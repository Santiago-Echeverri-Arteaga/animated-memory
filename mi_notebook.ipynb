# %% [markdown]
# <a href="https://colab.research.google.com/github/Santiago-Echeverri-Arteaga/animated-memory/blob/master/mi_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sección nueva
#
# *   Elemento de la lista
# *   Elemento de la lista

# %%
print("Hola Mundo")
print("Hello World")
# Out:
# Hola Mundo
# Hello World
